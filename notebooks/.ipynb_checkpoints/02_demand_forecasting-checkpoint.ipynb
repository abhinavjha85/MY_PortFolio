# %%
pip install prophet
# Out:
# Collecting prophet
#   Downloading prophet-1.3.0-py3-none-macosx_11_0_arm64.whl.metadata (3.5 kB)
# Collecting cmdstanpy>=1.0.4 (from prophet)
#   Downloading cmdstanpy-1.3.0-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy>=1.15.4 in /opt/anaconda3/lib/python3.13/site-packages (from prophet) (2.3.5)
# Requirement already satisfied: matplotlib>=2.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from prophet) (3.10.6)
# Requirement already satisfied: pandas>=1.0.4 in /opt/anaconda3/lib/python3.13/site-packages (from prophet) (3.0.2)
# Collecting holidays<1,>=0.25 (from prophet)
#   Downloading holidays-0.99-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: tqdm>=4.36.1 in /opt/anaconda3/lib/python3.13/site-packages (from prophet) (4.67.1)
# Collecting importlib_resources (from prophet)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: python-dateutil<3,>=2.9.0.post0 in /opt/anaconda3/lib/python3.13/site-packages (from holidays<1,>=0.25->prophet) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil<3,>=2.9.0.post0->holidays<1,>=0.25->prophet) (1.17.0)
# Collecting stanio<2.0.0,>=0.4.0 (from cmdstanpy>=1.0.4->prophet)
#   Downloading stanio-0.5.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->prophet) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->prophet) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->prophet) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->prophet) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->prophet) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->prophet) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=2.0.0->prophet) (3.2.5)
# Downloading prophet-1.3.0-py3-none-macosx_11_0_arm64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 3.6 MB/s  0:00:033.7 MB/s eta 0:00:0104
# Downloading holidays-0.99-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.1 MB/s  0:00:00
# Downloading cmdstanpy-1.3.0-py3-none-any.whl (99 kB)
# Downloading stanio-0.5.1-py3-none-any.whl (8.1 kB)
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Installing collected packages: stanio, importlib_resources, holidays, cmdstanpy, prophet
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [prophet]━━━ 4/5 [prophet]]
# Successfully installed cmdstanpy-1.3.0 holidays-0.99 importlib_resources-7.1.0 prophet-1.3.0 stanio-0.5.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from prophet import Prophet
import warnings
warnings.filterwarnings('ignore')
print("Libraries loaded! ✅")
# Out:
# Libraries loaded! ✅

# %%
df = pd.read_csv('/Users/abhinavjha/NeuralRetail/data/processed/clean_data.csv')
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
print(f"Data loaded: {df.shape} ✅")
# Out:
# Data loaded: (397924, 9) ✅

# %%
daily_sales = df.groupby(df['InvoiceDate'].dt.date)['TotalPrice'].sum().reset_index()
daily_sales.columns = ['ds', 'y']
daily_sales['ds'] = pd.to_datetime(daily_sales['ds'])
print(f"Daily sales: {daily_sales.shape} ✅")
daily_sales.tail()
# Out:
# Daily sales: (305, 2) ✅
#             ds          y
# 300 2011-12-05   58202.21
# 301 2011-12-06   46144.04
# 302 2011-12-07   69354.21
# 303 2011-12-08   50519.41
# 304 2011-12-09  184349.28

# %%
model = Prophet(seasonality_mode='multiplicative')
model.fit(daily_sales)
print("Model trained! ✅")
# Out:
# 09:18:40 - cmdstanpy - INFO - Chain [1] start processing
# 09:18:41 - cmdstanpy - INFO - Chain [1] done processing
# Model trained! ✅

# %%
future = model.make_future_dataframe(periods=30)
forecast = model.predict(future)
fig = model.plot(forecast)
plt.title('30-Day Sales Forecast')
plt.show()
print("Forecast done! ✅")
# Out:
# Forecast done! ✅
